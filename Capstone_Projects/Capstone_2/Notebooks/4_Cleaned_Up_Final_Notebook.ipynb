# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


#warnings
from warnings import simplefilter

#evaluation
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Import Data

# %%
#import x and change category fields
X = pd.read_csv('../data/final_data/X.csv',index_col = 0)
X= X.astype({'Week_Name':'category','Gender':'category'})

#import y and change category fields 
y = pd.read_csv('../data/final_data/y.csv',index_col = 0)

# %%
y =np.array(y)

# %% [markdown]
# ### Train_Test_Split

# %%
#train_test_split the data
from model import split
X_train, X_test, y_train, y_test = split(X,y)

# %% [markdown]
# ### Transform our Data

# %%
#transform our model 
from model import transform_model

X_train_trans_re, X_test_trans, y_train_re = transform_model(X_train, X_test,y_train)

# %% [markdown]
# ### Build and Evaluate our model

# %%
#build our model
from model import build_model

model1 =model(X_train_trans_re, X_test_trans, y_train_re, y_test)
model1.f1_score()
# Out:
# 0.41791044776119407

# %%
#confusion matrix
plt.clf
cm = confusion_matrix(y_test,model1.model())
disp = ConfusionMatrixDisplay(cm)
disp.plot()
txt ='Figure 8; Confusion Matrix for the KNN Model'
plt.text(.5,2,txt,ha='center')
plt.title("KNN Confusion Matrix")

plt.show()
