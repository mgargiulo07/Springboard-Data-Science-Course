# %%
import pandas as pd
import numpy as np

# %%
#Import Cities Data
cities_2018_disclosure = pd.read_csv('../raw_data/Cities/Cities Disclosing/2018_Cities_Disclosing_to_CDP.csv')
cities_2019_disclosure = pd.read_csv('../raw_data/Cities/Cities Disclosing/2019_Cities_Disclosing_to_CDP.csv')
cities_2020_disclosure = pd.read_csv('../raw_data/Cities/Cities Disclosing/2020_Cities_Disclosing_to_CDP.csv')

# %%
#combine files
cities_disclosure=[cities_2018_disclosure,cities_2019_disclosure,cities_2020_disclosure]
cities_disclosure= pd.concat(cities_disclosure).sort_values('Account Number').reset_index(drop=True)
cities_disclosure.head()

#cities_disclosure.shape (20168,13)
# Out:
#    Year Reported to CDP  Account Number     Organization     City  \
# 0                  2019            1093  City of Atlanta  Atlanta
# 1                  2018            1093  City of Atlanta  Atlanta
# 2                  2018            1184   City of Austin   Austin
# 3                  2020            1184   City of Austin   Austin
# 4                  2019            1184   City of Austin   Austin
#
#                     Country     CDP Region  \
# 0  United States of America  North America
# 1  United States of America  North America
# 2  United States of America  North America
# 3  United States of America  North America
# 4  United States of America  North America
#
#                                  Reporting Authority  Access  \
# 0  CDP Cities,ICLEI - Local Governments for Susta...  public
# 1                                         CDP Cities  public
# 2                                     C40,CDP Cities  public
# 3  C40,CDP Cities,ICLEI - Local Governments for S...  public
# 4  C40,CDP Cities,ICLEI - Local Governments for S...  public
#
#   First Time Discloser  Population  Population Year             City Location  \
# 0                   No    450182.0             2017    POINT (-84.388 33.749)
# 1                   No    450182.0             2017    POINT (-84.388 33.749)
# 2                   No   1265974.0             2017  POINT (-97.7431 30.2672)
# 3                   No    964254.0             2019  POINT (-97.7431 30.2672)
# 4                   No   1227000.0             2017  POINT (-97.7431 30.2672)
#
#                Last update
# 0  2020-06-25T04:52:51.327
# 1  2020-06-25T04:52:49.050
# 2  2020-06-25T04:52:49.050
# 3  2020-09-07T09:45:19.793
# 4  2020-06-25T04:52:51.327

# %%
#Adjust column names
cities_disclosure.columns=['Reporting_Year','Account_Num','Org','City','Country','CDP_Reg','Reporting_Auth',\
                          'Access','First_Time_Disc','Pop','Pop_Year','City_Loc','Last_Update']

# %% [markdown]
# ## Dealing with Nulls

# %% [markdown]
# ### City

# %%
#Lets look at nulls
cities_disclosure.isnull().sum()
# Out:
# Reporting_Year       0
# Account_Num          0
# Org                  0
# City               352
# Country              0
# CDP_Reg              0
# Reporting_Auth       0
# Access               0
# First_Time_Disc      0
# Pop                284
# Pop_Year             0
# City_Loc           438
# Last_Update          0
# dtype: int64

# %% [markdown]
# The dataset contains data from both inside and outside of the US. It may be more common for countries to not list a city (since they may not use cities). I'll set non-US nulls to "Not Listed" and remove US nulls if the number of missing data is less than 5%.

# %%
#Nulls from outside the US
cities_disclosure.loc[(cities_disclosure.City.isnull())&\
                      (cities_disclosure.Country!='United States of America'),'City']='Not Listed'

# %%
#Nulls from inside the US
num = cities_disclosure.loc[(cities_disclosure.City.isnull())&\
                      (cities_disclosure.Country=='United States of America')].shape[0]
denom = cities_disclosure['City'].shape[0]

print('Total percentage of missing nulls are {}%'.format(round((num/denom)*100,2)))
# Out:
# Total percentage of missing nulls are 2.03%

# %% [markdown]
# ### Pop

# %% [markdown]
# Find an example where we have populations for some dates but not others

# %%
#isolate an example
cities_disclosure.loc[cities_disclosure['Account_Num']==10894]
# Out:
#     Reporting_Year  Account_Num                  Org         City  \
# 33            2018        10894  City of Los Angeles  Los Angeles
# 34            2020        10894  City of Los Angeles  Los Angeles
# 35            2019        10894  City of Los Angeles  Los Angeles
#
#                      Country        CDP_Reg  \
# 33  United States of America  North America
# 34  United States of America  North America
# 35  United States of America  North America
#
#                                        Reporting_Auth      Access  \
# 33                                     C40,CDP Cities  non public
# 34  C40,CDP Cities,ICLEI - Local Governments for S...      public
# 35  C40,CDP Cities,ICLEI - Local Governments for S...      public
#
#    First_Time_Disc        Pop  Pop_Year                  City_Loc  \
# 33              No  4030904.0      2016  POINT (-118.244 34.0522)
# 34              No  4021488.0      2018  POINT (-118.244 34.0522)
# 35              No        NaN         0  POINT (-118.244 34.0522)
#
#                 Last_Update
# 33  2020-06-25T04:52:49.050
# 34  2020-09-07T09:45:19.793
# 35  2020-06-25T04:52:51.327

# %%
#fill the nulls with the mean values
cities_disclosure['Pop'] = \
cities_disclosure.groupby(['Account_Num'],sort=False)['Pop'].apply(lambda x: x.fillna(x.mean()))

# %%
#verify that our solution is correct
assert cities_disclosure.loc[35,'Pop']==4026196.0

# %% [markdown]
# Replace pop_year with average year (to match us taking the average population value)

# %%
#replace 0s with nulls
cities_disclosure['Pop_Year'] = \
cities_disclosure.groupby(['Account_Num'])['Pop_Year'].apply(lambda x: x.replace(0,np.nan))


#replace nulls with averag value

cities_disclosure['Pop_Year'] = \
cities_disclosure.groupby(['Account_Num'])['Pop_Year'].apply(lambda x: x.fillna(x.mean()))

# %%
assert cities_disclosure.loc[35,'Pop_Year']==2017

# %%
cities_disclosure.Pop_Year.unique()
# Out:
# array([2017. , 2019. , 2018. , 2015. , 2016. , 2020. , 2012. , 2011. ,
#        2017.5, 2013. , 2010. , 2014. , 2016.5,    nan, 2018.5, 2013.5,
#           7. , 1013. , 2007. ,  214. , 2005. , 2012.5, 2019.5,  216. ,
#         217. ,   19. , 2003. , 2014.5, 2009. , 2008. ,  218. ,  219. ,
#          21. , 1537. ,  211. , 2002. ])

# %% [markdown]
# From the output, we still have some issues. We need to cirlce back to these

# %% [markdown]
# # Responses

# %%
#pull in data and merge like above
Cities_2018_Responses = pd.read_csv('../raw_data/Cities/Cities Responses/2018_Full_Cities_Dataset.csv')
Cities_2019_Responses = pd.read_csv('../raw_data/Cities/Cities Responses/2019_Full_Cities_Dataset.csv')
Cities_2020_Responses = pd.read_csv('../raw_data/Cities/Cities Responses/2020_Full_Cities_Dataset.csv')

Cities_Responses=pd.concat([Cities_2018_Responses,Cities_2019_Responses,Cities_2020_Responses]).sort_values('Account Number').reset_index(drop=True)
Cities_Responses.head()
# Out:
#      Questionnaire  Year Reported to CDP  Account Number     Organization  \
# 0      Cities 2019                  2019            1093  City of Atlanta
# 1  CDP Cities 2018                  2018            1093  City of Atlanta
# 2      Cities 2019                  2019            1093  City of Atlanta
# 3      Cities 2019                  2019            1093  City of Atlanta
# 4      Cities 2019                  2019            1093  City of Atlanta
#
#                     Country     CDP Region                   Parent Section  \
# 0  United States of America  North America                    Opportunities
# 1  United States of America  North America              City Wide Emissions
# 2  United States of America  North America              Emissions Reduction
# 3  United States of America  North America              Emissions Reduction
# 4  United States of America  North America  Climate Hazards & Vulnerability
#
#                      Section Question Number  \
# 0              Opportunities             6.2
# 1         GHG Emissions Data             7.5
# 2  Mitigation Target setting            5.0a
# 3  Mitigation Target setting            5.0a
# 4            Climate Hazards             2.2
#
#                                        Question Name  Column Number  \
# 0  List any emission reduction, adaptation, water...              5
# 1  Please attach your city-wide inventory in the ...              4
# 2  Please provide details of your total city-wide...             12
# 3  Please provide details of your total city-wide...              9
# 4  Please identify and describe the factors that ...              2
#
#                                          Column Name  Row Number Row Name  \
# 0                                Project description           2      NaN
# 1                     Comment on level of confidence           1      NaN
# 2  Please indicate to which sector(s) the target ...           1      NaN
# 3  Target year absolute emissions (metric tonnes ...           1      NaN
# 4                                Support / Challenge           4      NaN
#
#                                      Response Answer Comments File Name  \
# 0  Renew Atlanta is an infrastructure improvement...      NaN       NaN
# 1  We were unable to retrieve natural gas data fr...      NaN       NaN
# 2                                    Public facility      NaN       NaN
# 3                                                NaN      NaN       NaN
# 4                                          Challenge      NaN       NaN
#
#               Last update
# 0  24/06/2020 05:30:36 AM
# 1  24/06/2020 05:28:18 AM
# 2  24/06/2020 05:30:36 AM
# 3  24/06/2020 05:30:36 AM
# 4  24/06/2020 05:30:36 AM

# %%
#drop the columns that are also present in the disclosure file
Cities_Responses.drop(columns=['Questionnaire','Organization','Country','CDP Region',\
                               'File Name','Last update','Comments'],inplace=True)

# %%
#rename columns
Cities_Responses.columns=['Year','Account_Num','Parent_Sect','Sect','Q_Num','Q_Name',\
                          'Col_Num','Col_Name','Row_Num','Row_Name','Answer']
Cities_Responses.head()
# Out:
#    Year  Account_Num                      Parent_Sect  \
# 0  2019         1093                    Opportunities
# 1  2018         1093              City Wide Emissions
# 2  2019         1093              Emissions Reduction
# 3  2019         1093              Emissions Reduction
# 4  2019         1093  Climate Hazards & Vulnerability
#
#                         Sect Q_Num  \
# 0              Opportunities   6.2
# 1         GHG Emissions Data   7.5
# 2  Mitigation Target setting  5.0a
# 3  Mitigation Target setting  5.0a
# 4            Climate Hazards   2.2
#
#                                               Q_Name  Col_Num  \
# 0  List any emission reduction, adaptation, water...        5
# 1  Please attach your city-wide inventory in the ...        4
# 2  Please provide details of your total city-wide...       12
# 3  Please provide details of your total city-wide...        9
# 4  Please identify and describe the factors that ...        2
#
#                                             Col_Name  Row_Num Row_Name  \
# 0                                Project description        2      NaN
# 1                     Comment on level of confidence        1      NaN
# 2  Please indicate to which sector(s) the target ...        1      NaN
# 3  Target year absolute emissions (metric tonnes ...        1      NaN
# 4                                Support / Challenge        4      NaN
#
#                                               Answer
# 0  Renew Atlanta is an infrastructure improvement...
# 1  We were unable to retrieve natural gas data fr...
# 2                                    Public facility
# 3                                                NaN
# 4                                          Challenge

# %%
#Create table of unique questions from the questionaire
Questionaire_Questions =Cities_Responses[['Year','Parent_Sect','Sect','Q_Num',\
                                          'Q_Name','Col_Num','Col_Name','Row_Num','Row_Name']].drop_duplicates()
Questionaire_Questions=Questionaire_Questions.sort_values(['Q_Num','Col_Num','Row_Num','Year']).reset_index(drop=True)
Questionaire_Questions.index=Questionaire_Questions.index.set_names(['Question_ID'])
Questionaire_Questions.reset_index(inplace=True)
Questionaire_Questions.head()
# Out:
#    Question_ID  Year Parent_Sect          Sect Q_Num  \
# 0            0  2018         NaN  Introduction   0.1
# 1            1  2019         NaN  Introduction   0.1
# 2            2  2020         NaN  Introduction   0.1
# 3            3  2018         NaN  Introduction   0.1
# 4            4  2019         NaN  Introduction   0.1
#
#                                               Q_Name  Col_Num  \
# 0  Please give a general description and introduc...        1
# 1  Please give a general description and introduc...        1
# 2  Please give a general description and introduc...        1
# 3  Please give a general description and introduc...        2
# 4  Please give a general description and introduc...        2
#
#                   Col_Name  Row_Num         Row_Name
# 0  Administrative boundary        1    City boundary
# 1  Administrative boundary        1    City boundary
# 2  Administrative boundary        1  Please complete
# 3      Description of city        1    City boundary
# 4      Description of city        1    City boundary

# %%
#create a new df that contains Account_Num(Key from disclosure DF) and Question_Id (Key from questionare_question df). 
df = Cities_Responses.merge(Questionaire_Questions,on=['Year','Q_Num','Q_Name','Col_Num','Col_Name','Row_Num','Row_Name'])[['Account_Num','Year','Question_ID','Answer']]
df.sort_values('Account_Num')
# Out:
#          Account_Num  Year  Question_ID  \
# 0               1093  2019        18980
# 290743          1093  2019         7402
# 291378          1093  2018         9600
# 291671          1093  2019         2380
# 292485          1093  2018        20668
# ...              ...   ...          ...
# 575441        848478  2020         2441
# 530785        848478  2020        18845
# 780519        848478  2020         2183
# 1051979       848478  2020        13157
# 744535        848478  2020        21324
#
#                                                     Answer
# 0        Renew Atlanta is an infrastructure improvement...
# 290743                  Extreme Precipitation > Rain storm
# 291378                                          Rain storm
# 291671                                                 NaN
# 292485                                                2020
# ...                                                    ...
# 575441                             Question not applicable
# 530785                             Question not applicable
# 780519                             Question not applicable
# 1051979                            Question not applicable
# 744535                                                 NaN
#
# [1542496 rows x 4 columns]

# %% [markdown]
# Lets test to make sure that the question_ID corresponds to the correct Answe. This test will:

# %%
#Create a function to test that our merges line up properly. 
def test_merge_Q_id(account_Num,Question_ID,answer):
    '''
    This is to make sure that I lined up the Questionare_Questions DF to the Cities_Response DataFrame.
    Enter an account_Num, Question_ID, and the answer that you are expecting
    '''
    

    qq=Questionaire_Questions.loc[Questionaire_Questions.Question_ID==Question_ID] 
    cr=Cities_Responses.loc[Cities_Responses['Account_Num']==account_Num]\
    [['Answer','Year','Q_Num','Q_Name','Col_Num','Col_Name','Row_Num','Row_Name']]
    result = cr.loc[(cr.Year.isin(qq.Year))&(cr.Q_Num.isin(qq.Q_Num))&(cr.Col_Num.isin(qq.Col_Num))&(cr.Row_Num.isin(qq.Row_Num)),'Answer']
    assert answer == result.values

# %%
#test the function by pluging in an account_num, quesitno_id and the expected answer
test_merge_Q_id(1093,7402,'Extreme Precipitation > Rain storm')
test_merge_Q_id(848478,18845,'Question not applicable')

# %% [markdown]
# All good! No errors

# %% [markdown]
# ## Cleaning up the df

# %%
df.dtypes
# Out:
# Account_Num     int64
# Year            int64
# Question_ID     int64
# Answer         object
# dtype: object

# %%
#Set to category for one hot encoding 
df.Year = df.Year.astype('category')
df.Question_ID = df.Question_ID.astype('category')

# %% [markdown]
# Check for nulls

# %%
df.isnull().sum()
# Out:
# Account_Num         0
# Year                0
# Question_ID         0
# Answer         401188
# dtype: int64

# %%
df.loc[df.Answer.isna()]
# Out:
#          Account_Num  Year Question_ID Answer
# 21             31174  2019       18980    NaN
# 42             35873  2019       18980    NaN
# 55             36036  2019       18980    NaN
# 76             44185  2019       18980    NaN
# 77             45219  2019       18980    NaN
# ...              ...   ...         ...    ...
# 1542460        74423  2018       20102    NaN
# 1542461        74423  2018       20108    NaN
# 1542462        74423  2018       20114    NaN
# 1542463        74423  2018       20096    NaN
# 1542491       834163  2019       12874    NaN
#
# [401188 rows x 4 columns]

# %% [markdown]
# we can remove these from our df since they are blanks

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    Account_Num  Year Question_ID  \
# 0         1093  2019       18980
# 1         1499  2019       18980
# 2         2430  2019       18980
# 3         3422  2019       18980
# 4        10495  2019       18980
#
#                                               Answer
# 0  Renew Atlanta is an infrastructure improvement...
# 1  Barcelona City Council is working to promote a...
# 2  In order to achieve net zero energy status, at...
# 3  Mayor's energy efficiency programmes for both ...
# 4  In  2011, The City of Las Vegas selected stree...

# %% [markdown]
# # Geospatial Analysis

# %%
cities_disclosure.City_Loc.unique()
# Out:
# array(['POINT (-84.388 33.749)', 'POINT (-97.7431 30.2672)',
#        'POINT (2.1775 41.3823)', nan, 'POINT (-73.2121 44.4759)',
#        'POINT (-87.6298 41.8781)', 'POINT (-74.0059 40.7128)',
#        'POINT (-0.07868 51.5048)', 'POINT (18.0686 59.3293)',
#        'POINT (24.941 60.1733)', 'POINT (-115.14 36.1699)',
#        'POINT (-118.244 34.0522)', 'POINT (-90.0715 29.9511)',
#        'POINT (10.7522 59.9139)', 'POINT (-111.498 40.6461)',
#        'POINT (-122.682 45.52)', 'POINT (-122.332 47.6062)',
#        'POINT (-9.30148 38.7637)', 'POINT (-123.114 49.2612)',
#        'POINT (12.5683 55.6761)', 'POINT (-1.51217 52.4066)',
#        'POINT (-3.17909 51.4816)', 'POINT (-4.21278 55.8593)',
#        'POINT (-77.0369 38.9072)', 'POINT (-95.3694 29.7602)',
#        'POINT (144.963 -37.8141)', 'POINT (12.2858 41.53)',
#        'POINT (139.41 35.41)', 'POINT (120.344 22.6297)',
#        'POINT (139.638 35.4437)', 'POINT (151.207 -33.8675)',
#        'POINT (28.0473 -26.2041)', 'POINT (-79.3832 43.6532)',
#        'POINT (38.7544 9.02887)', 'POINT (4.89516 52.3702)',
#        'POINT (23.7275 37.9838)', 'POINT (100.556 13.7712)',
#        'POINT (7.5928 47.5619)', 'POINT (13.405 52.52)',
#        'POINT (-74.0721 4.711)', 'POINT (-58.3816 -34.6037)',
#        'POINT (-49.2647 -25.4311)', 'POINT (77.1025 28.704)',
#        'POINT (105.815 21.0258)', 'POINT (28.9784 41.0082)',
#        'POINT (106.66 10.7626)', 'POINT (8.67243 49.3988)',
#        'POINT (106.865 -6.1751)', 'POINT (3.3792 6.52437)',
#        'POINT (67.1281 24.9108)', 'POINT (114.14 22.2881)',
#        'POINT (-77.0283 -12.0433)', 'POINT (-3.38756 40.1076)',
#        'POINT (-99.1332 19.4326)', 'POINT (9.08635 45.8026)',
#        'POINT (37.6173 55.7558)', 'POINT (2.35222 48.8566)',
#        'POINT (-43.5614 -22.9054)', 'POINT (-111.891 40.7608)',
#        'POINT (4.45093 51.9164)', 'POINT (-70.6693 -33.4489)',
#        'POINT (-75.1638 39.9523)', 'POINT (-122.419 37.7749)',
#        'POINT (-46.7382 -23.5595)', 'POINT (21.0122 52.2297)',
#        'POINT (126.949 35.1542)', 'POINT (126.978 37.5665)',
#        'POINT (121.564 25.0375)', 'POINT (138.601 -34.9285)',
#        'POINT (-104.985 39.7376)', 'POINT (-71.0598 42.3584)',
#        'POINT (-72.9276 41.3093)', 'POINT (-70.2553 43.6615)',
#        'POINT (-90.1994 38.627)', 'POINT (8.53918 47.3686)',
#        'POINT (-114.071 51.0486)', 'POINT (26.5536 38.3434)',
#        'POINT (-43.9345 -19.9167)', 'POINT (-76.6122 39.2904)',
#        'POINT (4.34878 50.8505)', 'POINT (-84.512 39.1031)',
#        'POINT (18.4239 -33.9253)', 'POINT (-81.6944 41.4993)',
#        'POINT (-96.8004 32.7801)', 'POINT (-83.0457 42.3314)',
#        'POINT (31.0218 -29.8587)', 'POINT (28.3462 -26.1777)',
#        'POINT (-48.3936 -10.7183)', 'POINT (-103.35 20.6597)',
#        'POINT (9.99368 53.5511)', 'POINT (-80.1918 25.7617)',
#        'POINT (-34.8829 -8.05783)', 'POINT (-75.5735 6.22729)',
#        'POINT (-112.074 33.4484)', 'POINT (-79.9959 40.4406)',
#        'POINT (-121.494 38.5816)', 'POINT (-93.2667 44.9833)',
#        'POINT (51 30)', 'POINT (-121.886 37.3382)',
#        'POINT (-117.17 32.7181)', 'POINT (34.7823 32.0816)',
#        'POINT (7.668 45.1006)', 'POINT (-0.3763 39.4699)',
#        'POINT (39.2083 -6.79235)', 'POINT (-73.554 45.5087)',
#        'POINT (-46.9372 -22.744)', 'POINT (-2.15783 53.4576)',
#        'POINT (136.906 35.1815)', 'POINT (-7.56806 33.5206)',
#        'POINT (88.3639 22.5726)', 'POINT (80.2425 13.0992)',
#        'POINT (77.5946 12.9716)', 'POINT (36.8219 -1.29206)',
#        'POINT (75.7873 26.9124)', 'POINT (103.82 1.35208)',
#        'POINT (-47.8822 -15.7942)', 'POINT (15.2663 -4.44193)',
#        'POINT (-4.0083 5.36)', 'POINT (-17.366 14.7645)',
#        'POINT (3.94704 7.37753)', 'POINT (-76.532 3.45164)',
#        'POINT (-0.16819 5.56543)', 'POINT (28.3111 -28.2423)',
#        'POINT (7.39857 9.07647)', 'POINT (26.8344 38.1951)',
#        'POINT (-79.9223 -2.17099)', 'POINT (24.7536 59.437)',
#        'POINT (25.2797 54.6872)', 'POINT (14.2514 40.842)',
#        'POINT (-9.13933 38.7223)', 'POINT (47.5079 -18.8792)',
#        'POINT (8.898 39.7207)', 'POINT (12.3211 45.4333)',
#        'POINT (11.3566 46.4997)', 'POINT (9.31841 44.348)',
#        'POINT (12.518 41.913)', 'POINT (10.8774 44.4376)',
#        'POINT (11.3387 44.4938)', 'POINT (10.023 45.1405)',
#        'POINT (14.1399 42.3828)', 'POINT (9.08065 45.8008)',
#        'POINT (11.2558 43.7696)', 'POINT (11.619 44.8357)',
#        'POINT (14.3333 41.0667)', 'POINT (-90.049 35.1495)',
#        'POINT (24.1052 56.9496)', 'POINT (13.3995 42.3505)',
#        'POINT (9.83632 44.111)', 'POINT (10.6174 43.8399)',
#        'POINT (9.0371 45.8315)', 'POINT (12.5059 41.8823)',
#        'POINT (12.895 43.9012)', 'POINT (10.3279 44.8015)',
#        'POINT (14.2135 42.4639)', 'POINT (11.8768 45.4064)',
#        'POINT (9.69264 45.052)', 'POINT (12.5695 44.0678)',
#        'POINT (13.7188 42.6659)', 'POINT (8.55537 45.9283)',
#        'POINT (6.9583 50.9414)', 'POINT (30.3794 -29.6006)',
#        'POINT (-38.5023 -12.973)', 'POINT (-49.2648 -16.6869)',
#        'POINT (-78.5167 -0.2333)', 'POINT (-58.2987 -34.7112)',
#        'POINT (-98.4936 29.4241)', 'POINT (-86.1785 39.7676)',
#        'POINT (-81.3792 28.5383)', 'POINT (-82.9988 39.9612)',
#        'POINT (-75.6972 45.4215)', 'POINT (-113.491 53.5444)',
#        'POINT (-80.8431 35.2271)', 'POINT (23.3219 42.6977)',
#        'POINT (14.5058 46.0569)', 'POINT (15.9819 45.815)',
#        'POINT (9.7356 52.3739)', 'POINT (8.46603 49.4875)',
#        'POINT (149.124 -35.3075)', 'POINT (4.3007 52.0705)',
#        'POINT (174.742 -36.8153)', 'POINT (115.861 -31.9526)',
#        'POINT (174.776 -41.2865)', 'POINT (55.2708 25.2048)',
#        'POINT (13.0038 55.605)', 'POINT (-57.5759 -25.2637)',
#        'POINT (-74.7782 10.9815)', 'POINT (-77.067 -12.0917)',
#        'POINT (-6.8498 33.9716)', 'POINT (126.805 37.17)',
#        'POINT (-41.6667 -20.7)', 'POINT (-2.67 42.84)',
#        'POINT (-0.88701 41.6086)', 'POINT (-8.6291 41.1579)',
#        'POINT (-71.4128 41.824)', 'POINT (-94.573 39.1429)',
#        'POINT (-85.6784 38.196)', 'POINT (-77.436 37.5407)',
#        'POINT (-86.7816 36.1627)', 'POINT (157.59 21.28)',
#        'POINT (-77.6109 43.161)', 'POINT (-106.485 31.7619)',
#        'POINT (-78.6382 35.7796)', 'POINT (30.9328 -17.8284)',
#        'POINT (28.1881 -25.7461)', 'POINT (-13.2317 8.4657)',
#        'POINT (-122.159 38.0494)', 'POINT (22.2666 60.4518)',
#        'POINT (35.334 36.995)', 'POINT (44.8271 41.7151)',
#        'POINT (7.26195 43.7102)', 'POINT (-87.2044 14.1051)',
#        'POINT (-117.069 32.5026)', 'POINT (-68.8458 -32.8894)',
#        'POINT (-101.684 21.1221)', 'POINT (-110.961 29.0892)',
#        'POINT (-73.0498 -36.827)', 'POINT (-68.15 -16.5)',
#        'POINT (-75.329 -11.0557)', 'POINT (-99.0173 19.3599)',
#        'POINT (-64.1888 -31.4201)', 'POINT (-75.5501 10.4218)',
#        'POINT (-106.076 28.6368)', 'POINT (9.9326 -84.0796)',
#        'POINT (-73.1227 7.11034)', 'POINT (-103.407 25.5428)',
#        'POINT (-89.5926 20.9674)', 'POINT (-47.4221 -23.4775)',
#        'POINT (-48.5482 -27.595)', 'POINT (-37.7142 -7.10801)',
#        'POINT (-52.2663 -15.882)', 'POINT (-46.5338 -23.4542)',
#        'POINT (-35.2009 -5.77925)', 'POINT (-35.718 -9.67342)',
#        'POINT (-60.0217 -3.11902)', 'POINT (-40.3776 -20.3338)',
#        'POINT (-34.8639 -7.16882)', 'POINT (-38.057 -6.5344)',
#        'POINT (-46.3289 -23.9679)', 'POINT (-106.425 31.6904)',
#        'POINT (-89.3818 43.0728)', 'POINT (-79.792 36.0726)',
#        'POINT (-63.5714 44.6478)', 'POINT (41.7606 88.3201)',
#        'POINT (-97.3308 32.7555)', 'POINT (-78.8784 42.8864)',
#        'POINT (-118.194 33.7701)', 'POINT (-119.773 36.7468)',
#        'POINT (-79.8661 43.25)', 'POINT (38.8468 -76.2851)',
#        'POINT (-81.2497 42.9837)', 'POINT (-79.2469 43.1594)',
#        'POINT (-122.271 37.8044)', 'POINT (-117.084 32.64)',
#        'POINT (-83.5552 41.6639)', 'POINT (-149.9 61.2181)',
#        'POINT (-106.67 52.1332)', 'POINT (-123.366 48.4284)',
#        'POINT (-93.09 44.9537)', 'POINT (-96.6989 33.0198)',
#        'POINT (-83.0364 42.3149)', 'POINT (-97.1375 49.8997)',
#        'POINT (-5.35359 36.1408)', 'POINT (-8.59723 40.8901)',
#        'POINT (-8.17286 41.4508)', 'POINT (-8.68599 39.2367)',
#        'POINT (-7.93044 37.0194)', 'POINT (-7.91247 40.6566)',
#        'POINT (-9.07907 38.6608)', 'POINT (-9.42229 38.697)',
#        'POINT (-16.9241 32.6669)', 'POINT (90.4125 23.8103)',
#        'POINT (7.42081 43.7374)', 'POINT (-46.7402 -23.3612)',
#        'POINT (113.813 22.9175)', 'POINT (-90.5069 14.6349)',
#        'POINT (-51.0705 0.0356)', 'POINT (-37.0731 -10.9472)',
#        'POINT (-80.2442 36.0999)', 'POINT (-106.837 39.195)',
#        'POINT (147.281 -42.8901)', 'POINT (-111.94 33.4255)',
#        'POINT (-94.1719 36.0821)', 'POINT (-122.444 47.2529)',
#        'POINT (-92.2896 34.7465)', 'POINT (-83.9207 35.9606)',
#        'POINT (-76.3055 40.0379)', 'POINT (-80.9645 46.5268)',
#        'POINT (-105.084 40.5853)', 'POINT (-123.087 44.0519)',
#        'POINT (-105.081 39.7047)', 'POINT (-122.081 37.6689)',
#        'POINT (-80.1495 26.0112)', 'POINT (80.25 43.55)',
#        'POINT (-81.0998 32.0835)', 'POINT (-83.743 42.2808)',
#        'POINT (-89.2477 48.3809)', 'POINT (-92.3341 38.9517)',
#        'POINT (-73.7562 42.6526)', 'POINT (-105.252 40.0274)',
#        'POINT (-78.8986 35.994)', 'POINT (-86.5264 39.1653)',
#        'POINT (-118.481 34.0219)', 'POINT (-91.5302 41.6611)',
#        'POINT (-111.631 35.1992)', 'POINT (-82.5515 35.5951)',
#        'POINT (-90.5071 42.5006)', 'POINT (-122.143 37.4419)',
#        'POINT (-121.989 37.5483)', 'POINT (-119.814 39.5296)',
#        'POINT (150.893 -34.4278)', 'POINT (174.354 -39.1011)',
#        'POINT (114.325 30.6435)', 'POINT (120.356 36.1105)',
#        'POINT (104.076 30.6719)', 'POINT (113.264 23.1291)',
#        'POINT (121.567 38.9389)', 'POINT (106.806 -6.5971)',
#        'POINT (35.9284 31.9454)', 'POINT (125.625 7.07475)',
#        'POINT (121.061 14.5869)', 'POINT (120.862 15.6835)',
#        'POINT (116.831 -1.26539)', 'POINT (121.024 14.5547)',
#        'POINT (121.02 14.4793)', 'POINT (101.595 3.1279)',
#        'POINT (101.687 3.139)', 'POINT (120.227 22.9999)',
#        'POINT (100.992 1.45556)', 'POINT (120.647 24.1619)',
#        'POINT (121.013 24.8269)', 'POINT (121.301 24.9931)',
#        'POINT (25.65 60.9833)', 'POINT (9.5364 55.7113)',
#        'POINT (24.6559 60.2055)', 'POINT (0.1 49.49)',
#        'POINT (11.6276 52.1205)', 'POINT (6.88452 51.4186)',
#        'POINT (12.1405 54.0887)', 'POINT (-21.8174 64.1265)',
#        'POINT (5.84282 51.8449)', 'POINT (10.395 63.4305)',
#        'POINT (8.0182 58.1599)', 'POINT (17.0385 51.1079)',
#        'POINT (-1.00495 37.799)', 'POINT (-0.48149 38.3452)',
#        'POINT (20.263 63.8258)', 'POINT (17.635 59.8536)',
#        'POINT (15.2066 59.2741)', 'POINT (-1.88076 50.7192)',
#        'POINT (-1.1333 52.6333)', 'POINT (30.2513 -30.6218)',
#        'POINT (29.974 -22.7695)', 'POINT (29.974 -24.8335)',
#        'POINT (18.627 -32.0951)', 'POINT (27.6435 32.9344)',
#        'POINT (-49.0587 -22.3145)', 'POINT (-75.8814 8.74798)',
#        'POINT (-49.3762 -20.8118)', 'POINT (-47.1294 -23.5428)',
#        'POINT (-66.1653 -17.414)', 'POINT (-75.6906 4.80871)',
#        'POINT (-44.2012 -19.9673)', 'POINT (-51.1505 -23.3356)',
#        'POINT (-48.8407 -26.301)', 'POINT (-46.8725 -23.3646)',
#        'POINT (-45.1201 -22.7339)', 'POINT (-79.0048 -2.90841)',
#        'POINT (-47.3974 -22.5665)', 'POINT (-46.8978 -23.1857)',
#        'POINT (-47.8466 -23.3492)', 'POINT (-48.3243 -10.2491)',
#        'POINT (-46.5167 -23.6583)', 'POINT (23.5328 46.7919)',
#        'POINT (-49.1964 -18.4056)', 'POINT (-46.9838 -23.0307)',
#        'POINT (-51.9383 -23.4257)', 'POINT (-48.9111 -20.7371)',
#        'POINT (-53.4595 -24.9578)', 'POINT (-48.1766 -21.7946)',
#        'POINT (-47.5137 -23.2102)', 'POINT (-50.4328 -21.2089)',
#        'POINT (-40.5079 -9.3835)', 'POINT (-46.732 -23.3094)',
#        'POINT (-45.8783 -23.1848)', 'POINT (-46.3919 -23.963)',
#        'POINT (-47.9947 -21.1451)', 'POINT (-47.7463 -23.167)',
#        'POINT (-47.2669 -22.8219)', 'POINT (-46.5885 -23.318)',
#        'POINT (-60.6779 2.83067)', 'POINT (-49.0717 -26.9166)',
#        'POINT (-7.81289 41.1076)', 'POINT (-8.7476 41.381)',
#        'POINT (-8.29224 41.4443)', 'POINT (-8.44582 40.5753)',
#        'POINT (-16.9833 32.6333)', 'POINT (-7.58 38.85)',
#        'POINT (-8.43821 41.5337)', 'POINT (-68.833 -32.8941)',
#        'POINT (-51.1862 -29.9133)', 'POINT (-47.1367 -23.3058)',
#        'POINT (-46.4234 -23.8994)', 'POINT (-81.0348 34.0007)',
#        'POINT (-117.999 33.6603)', 'POINT (-80.3036 25.9861)',
#        'POINT (-8.65731 41.3028)', 'POINT (-122.138 37.3797)',
#        'POINT (-76.0026 37.2265)', 'POINT (-93.3273 45.601)',
#        'POINT (-80.0534 26.7153)', 'POINT (121.446 25.0111)',
#        'POINT (120.47 22.6558)', 'POINT (-79.5552 9.11862)',
#        'POINT (-43.1184 -22.8928)', 'POINT (-87.8406 42.2586)',
#        'POINT (-2.9913 53.0466)', 'POINT (-79.9414 37.271)',
#        'POINT (-118.362 34.09)', 'POINT (10.5938 59.9205)',
#        'POINT (-86.118 39.9784)', 'POINT (18.6466 54.352)',
#        'POINT (25.6345 42.4258)', 'POINT (-73.7126 45.6207)',
#        'POINT (-75.1195 40.1241)', 'POINT (9.79217 54.9138)',
#        'POINT (12.2898 55.6563)', 'POINT (-122.348 37.9358)',
#        'POINT (-122.876 42.3265)', 'POINT (21.1655 42.6629)',
#        'POINT (-72.6144 42.3048)', 'POINT (-71.0826 42.3934)',
#        'POINT (153.533 -28.6534)', 'POINT (19.2594 42.4304)',
#        'POINT (-75.2207 40.6884)', 'POINT (27.4626 42.5048)',
#        'POINT (-84.1503 10.0035)', 'POINT (-83.9833 9.91667)',
#        'POINT (10.4047 54.8914)', 'POINT (9.9958 57.4568)',
#        'POINT (-80.4139 37.2296)', 'POINT (-90.1843 38.8906)',
#        'POINT (-122.479 48.7519)', 'POINT (-70.9342 41.6362)',
#        'POINT (12.5921 56.0308)', 'POINT (35.0378 -15.8028)',
#        'POINT (10.15 55.9757)', 'POINT (12.5049 55.8835)',
#        'POINT (9.54153 57.1453)', 'POINT (-89.839 44.3603)',
#        'POINT (-78.9288 43.9368)', 'POINT (-70.8967 42.5195)',
#        'POINT (-91.4032 31.5604)', 'POINT (-18.1262 65.6885)',
#        'POINT (-3.7537 5.2259)', 'POINT (43.2473 -11.7172)',
#        'POINT (6.23478 46.3833)', 'POINT (19.8187 41.3275)',
#        'POINT (12.4887 55.7335)', 'POINT (-68.8154 -32.8421)',
#        'POINT (-70.6092 -33.4313)', 'POINT (-15.4789 12.7095)',
#        'POINT (9.87264 55.471)', 'POINT (11.5191 3.86181)',
#        'POINT (-106.374 39.6403)', 'POINT (-80.561 43.42)',
#        'POINT (-97.1331 33.2148)', 'POINT (43.589 -79.6441)',
#        'POINT (-88.263 42.0604)', 'POINT (-78.4767 38.0293)',
#        'POINT (-121.741 38.5449)', 'POINT (-77.0075 38.9779)',
#        'POINT (123.378 48.4594)', 'POINT (-79.0558 35.9132)',
#        'POINT (-122.4 37.6808)', 'POINT (-122.156 37.7249)',
#        'POINT (-122.031 36.9741)', 'POINT (-121.93 37.7)',
#        'POINT (-118.4 34.02)', 'POINT (-118.405 33.8889)',
#        'POINT (-123.072 49.32)', 'POINT (-87.6898 42.0669)',
#        'POINT (-80.0684 26.6168)', 'POINT (174.908 -41.2092)',
#        'POINT (121.058 13.7565)', 'POINT (121.089 14.2843)',
#        'POINT (124.632 8.45423)', 'POINT (0.16353 52.2077)',
#        'POINT (1.2974 52.6309)', 'POINT (18.5305 54.5189)',
#        'POINT (-1.4065 50.9074)', 'POINT (26.7219 58.38)',
#        'POINT (23.0634 40.7505)', 'POINT (36.08 -0.30309)',
#        'POINT (34.7679 -0.0917)', 'POINT (15.6216 58.4109)',
#        'POINT (23.7214 56.6511)', 'POINT (17.0658 -22.5609)',
#        'POINT (23.3137 55.9349)', 'POINT (21.0167 56.5167)',
#        'POINT (14.8091 56.8777)', 'POINT (15.5866 56.1616)',
#        'POINT (24.35 55.7333)', 'POINT (8.77245 58.4618)',
#        'POINT (24.4966 58.3858)', 'POINT (13.1569 55.3751)',
#        'POINT (-56.4894 -21.1254)', 'POINT (-48.9207 -27.0936)',
#        'POINT (-48.4441 -22.8852)', 'POINT (-46.2569 -23.9946)',
#        'POINT (-44.1982 -20.1427)', 'POINT (-46.0599 -23.8081)',
#        'POINT (-35.8808 -7.2291)', 'POINT (-46.328 -22.8403)',
#        'POINT (-72.6761 -7.62799)', 'POINT (-50.2475 -20.2858)',
#        'POINT (-41.2683 -21.8323)', 'POINT (-44.2442 -22.9983)',
#        'POINT (-38.9647 -12.2597)', 'POINT (-48 -22)',
#        'POINT (-48.5755 -22.3028)', 'POINT (-51.3856 -22.1276)',
#        'POINT (-48.9595 -15.8545)', 'POINT (-50.4892 -17.9685)',
#        'POINT (-47.4136 -22.7536)', 'POINT (-45.732 -22.6874)',
#        'POINT (-51.1493 -29.761)', 'POINT (-23.76 -45.41)',
#        'POINT (-50.5196 -21.934)', 'POINT (-57.4858 -14.6194)',
#        'POINT (-69.9406 -4.21528)', 'POINT (-75.24 4.44851)',
#        'POINT (-81.6976 12.5794)', 'POINT (-3.63354 40.4712)',
#        'POINT (-74.2127 11.2453)', 'POINT (-75.3906 9.30457)',
#        'POINT (-12.1078 -76.9989)', 'POINT (-77.0273 -12.0977)',
#        'POINT (-63.4884 -21.2666)', 'POINT (-71.5366 -16.3994)',
#        'POINT (-70.684 -33.2043)', 'POINT (-70.5302 -33.454)',
#        'POINT (-68.8342 -32.9199)', 'POINT (-68.8122 -32.9775)',
#        'POINT (-67.7002 -53.786)', 'POINT (12.4754 55.6425)',
#        'POINT (118.797 32.0603)', 'POINT (10.521 57.4427)',
#        'POINT (23.569 46.0823)', 'POINT (-64.5188 44.3786)',
#        'POINT (-79.0204 43.8509)', 'POINT (-122.75 53.9171)',
#        'POINT (33.7741 -13.9626)', 'POINT (29.3599 -3.36137)',
#        'POINT (12.5247 -22.9389)', 'POINT (37.6706 -6.8304)',
#        'POINT (-122.232 37.8244)', 'POINT (-80.1233 25.8789)',
#        'POINT (-99.2453 19.4631)', 'POINT (40.6854 -14.5656)',
#        'POINT (121.763 24.7309)', 'POINT (-122.285 37.8313)',
#        'POINT (27.7491 -15.8613)', 'POINT (6.18441 48.6921)',
#        'POINT (26.6658 47.7407)', 'POINT (-69.3305 -20.4895)',
#        'POINT (12.2387 55.795)', 'POINT (30.5256 39.7667)',
#        'POINT (11.9645 55.6013)', 'POINT (12.4058 55.9747)',
#        'POINT (41.6754 -86.2532)', 'POINT (-74.27 40.73)',
#        'POINT (12.2349 55.931)', 'POINT (34.344 31.3231)',
#        'POINT (-73.8167 43.0333)', 'POINT (80.3659 26.1901)',
#        'POINT (-80.13 25.7906)', 'POINT (-122.032 37.323)',
#        'POINT (-77.0362 -12.0271)', 'POINT (-77.0051 -12.1453)',
#        'POINT (-23 46.5)', 'POINT (-79.7736 8.88289)',
#        'POINT (-46.7929 -22.8767)', 'POINT (18.2948 57.6348)',
#        'POINT (16.3484 57.9587)', 'POINT (-67.6955 -34.978)',
#        'POINT (-3.99313 -79.2042)', 'POINT (-90.42 -0.38)',
#        'POINT (-77.0667 -11.95)', 'POINT (-76.1979 4.08618)',
#        'POINT (-75.3739 6.15316)', 'POINT (-73.8724 7.06066)',
#        'POINT (27.7617 59.3958)', 'POINT (24.5637 65.7364)',
#        'POINT (12.3923 54.0865)', 'POINT (22.2897 55.2522)',
#        'POINT (-76.3036 3.53944)', 'POINT (-73.0979 7.07001)',
#        'POINT (36.9218 -17.8503)', 'POINT (30.8384 -20.0792)',
#        'POINT (18.6735 44.5375)', 'POINT (-34.9268 -7.12505)',
#        'POINT (40.5178 -12.9732)', 'POINT (-40.7323 -15.0364)',
#        'POINT (-91.4976 40.0428)', 'POINT (-91.2396 43.8014)',
#        'POINT (-90.0542 29.9164)', 'POINT (-91.2073 30.4475)',
#        'POINT (-3.9674 5.3602)', 'POINT (-71.2269 42.4443)',
#        'POINT (122.163 37.4522)', 'POINT (12.0878 55.6419)',
#        'POINT (-117.293 33.0454)', 'POINT (-105.5 40.15)',
#        'POINT (106.038 39.4817)', 'POINT (24.5551 81.78)',
#        'POINT (27.3364 82.5307)', 'POINT (90.5776 41.5236)',
#        'POINT (-90.192 41.839)', 'POINT (42.0736 88.148)',
#        'POINT (-84.4805 42.7347)', 'POINT (-93.45 45.2611)',
#        'POINT (-91.6663 44.0554)', 'POINT (113.994 46.8721)',
#        'POINT (-106 35.5)', 'POINT (-109.54 38.57)',
#        'POINT (121.984 47.548)', 'POINT (-121.844 47.53)',
#        'POINT (-80.216 26.4986)', 'POINT (-27 11)',
#        'POINT (29.0585 40.98)', 'POINT (28 40)', 'POINT (27.35 47.1)',
#        'POINT (-102.546 20.2903)', 'POINT (-104.436 19.6031)',
#        'POINT (-102.132 20.4489)', 'POINT (-103.24 20.8555)',
#        'POINT (-104.367 19.7682)', 'POINT (-104.783 20.517)',
#        'POINT (-103.191 20.2962)', 'POINT (-104.38 19.34)',
#        'POINT (-45.548 -22.9576)', 'POINT (-74.2642 4.73245)',
#        'POINT (-74.2302 4.70592)', 'POINT (-73.9384 4.9075)',
#        'POINT (-83.9194 9.86444)', 'POINT (-9.38811 38.7984)',
#        'POINT (-7.43235 39.2914)', 'POINT (-7.1753 41.51)',
#        'POINT (-7.49189 39.8239)', 'POINT (-8.49835 41.1887)',
#        'POINT (-8.8576 40.1521)', 'POINT (-8.01968 37.1377)',
#        'POINT (1.754 53.792)', 'POINT (-58.5544 -9.86825)',
#        'POINT (-58.3589 -10.3178)', 'POINT (-76.4336 8.85111)',
#        'POINT (8.34552 -76.3414)', 'POINT (10.3218 36.8725)',
#        'POINT (31.1808 -10.2129)', 'POINT (-87.6792 14.3194)',
#        'POINT (61 31)', 'POINT (1.21333 6.42611)',
#        'POINT (-5.0149 7.4137)', 'POINT (11.5167 3.8667)',
#        'POINT (11.31 3.52)', 'POINT (-88.8667 13.5)',
#        'POINT (15.7278 -88.5944)', 'POINT (10.8939 43.05)',
#        'POINT (-46.8729 -23.5114)', 'POINT (-7.7879 41.8266)',
#        'POINT (-98.7556 20.1318)', 'POINT (-9.32771 38.9385)',
#        'POINT (-70.031 41.9305)', 'POINT (76.2673 9.93123)',
#        'POINT (13.1368 46.279)', 'POINT (100.383 5.38333)',
#        'POINT (17.7234 59.6191)', 'POINT (-100.812 20.5222)',
#        'POINT (125.97 9.869)', 'POINT (-80.1484 25.9812)',
#        'POINT (27.8903 39.6533)', 'POINT (-0.32574 51.448)'], dtype=object)

# %%
cities_disclosure.rename(columns={'City_Loc':'geometry'},inplace=True)

# %%
cities_disclosure.loc[cities_disclosure.geometry=='POINT (2.1775 41.3823)']
# Out:
#    Reporting_Year  Account_Num                      Org       City Country  \
# 5            2020         1499  Ajuntament de Barcelona  Barcelona   Spain
# 6            2019         1499  Ajuntament de Barcelona  Barcelona   Spain
# 7            2018         1499  Ajuntament de Barcelona  Barcelona   Spain
#
#   CDP_Reg                                     Reporting_Auth  Access  \
# 5  Europe  C40,CDP Cities,ICLEI - Local Governments for S...  public
# 6  Europe  C40,CDP Cities,ICLEI - Local Governments for S...  public
# 7  Europe                                     C40,CDP Cities  public
#
#   First_Time_Disc        Pop  Pop_Year                geometry  \
# 5              No  1636762.0    2019.0  POINT (2.1775 41.3823)
# 6              No  1620343.0    2018.0  POINT (2.1775 41.3823)
# 7              No  1604555.0    2015.0  POINT (2.1775 41.3823)
#
#                Last_Update
# 5  2020-09-07T09:45:19.793
# 6  2020-06-25T04:52:51.327
# 7  2020-06-25T04:52:49.050

# %%
#remove null geopoints from the dataset
CD_df = cities_disclosure.dropna()

# %%
#add Lat Long coords
CD_df['lat']=CD_df.geometry.apply(lambda x: x.split(' ')[2].strip(')'))
CD_df['long']=CD_df.geometry.apply(lambda x: x.split(' ')[1].strip('('))
# Out:
# /var/folders/r8/kdff6gm9553_wdcqb3x5r7vh0000gq/T/ipykernel_56269/742568004.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CD_df['lat']=CD_df.geometry.apply(lambda x: x.split(' ')[2].strip(')'))
# /var/folders/r8/kdff6gm9553_wdcqb3x5r7vh0000gq/T/ipykernel_56269/742568004.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CD_df['long']=CD_df.geometry.apply(lambda x: x.split(' ')[1].strip('('))

# %%
import folium

# %%
#Create a map
map1 = folium.Map(
    tiles='cartodbpositron',
    zoom_start=12)

CD_df.apply(lambda row:folium.CircleMarker(radius=3,location=[row["lat"], row["long"]],fill=False,color='blue').add_to(map1),axis=1)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7cc0e65b9affa1590a187ab0fb69cb14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7cc0e65b9affa1590a187ab0fb69cb14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7cc0e65b9affa1590a187ab0fb69cb14 = L.map(
#                 &quot;map_7cc0e65b9affa1590a187ab0fb69cb14&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43b50986019c7f064e737cc717ade599 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7cc0e65b9affa1590a187ab0fb69cb14);
#
#
#             var circle_marker_2bd57220fa927d7eef8edb507f1a28f9 = L.circleMarker(
#                 [33.749, -84.388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7cc0e65b9affa1590a187ab0fb69cb14);
#
#
#             var circle_marker_a4455bb96e4e21843901e64315791e76 = L.circleMarker(
#                 [33.749, -84.388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7cc0e65b9affa1590a187ab0fb69cb14);
#
#
#             var circle_marker_543cb72881bc8e579f7ec3e0d8193c83 = L.circleMarker(
#                 [30.2672, -97.7431],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7cc0e65b9affa1590a187ab0fb69cb14);
#
#
#             var circle_marker_d2d4d4194b610fb854d5d5f6a63fe454 = L.circleMarker(
#                 [30.2672, -97.7431],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7cc0e65b9affa1590a187ab0fb69cb14);
#
#
#             var circle_marker_3e7e3e33e63bbe889bd84e94e2145394 = L.circleMarker(
#                 [30.2672, -97.7431],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7cc0e65b9affa1590a187ab0fb69cb14);
#
#
#             var circle_marker_4d511eb6baeae2c0e1eab27cb158d96f = L.circleMarker(
#                 [41.3823, 2.1775],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7cc0e65b9affa159

# %% [markdown]
# # Goal(s)

# %% [markdown]
# - Use Answers for Question IDs to find clusters?
# - Use Answers to predict Country?
